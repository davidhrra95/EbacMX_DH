# %%
#Aplicar los 3 puntos anteriores a un ejemplo donde se busca un archivo “test.txt” que NO existe en el directorio donde se está buscando.  
#1.-Generar las excepciones y mensajes de error correspondientes.
#2.-Excepciones y las funciones TRY/EXCEPT 
#3.-Ejemplos con TRY/EXCEPT/ELSE/FINALLY 

import os

nombre = 'text.txt'

def localización():
    assert os.path.exists(nombre), 'Archivo no encontrado'

try:
    localización()
    print('Archivo encontrado')
except:
    print('Archivo no encontrado')
else:
    archivo2 = open(nombre)
    print('Archivo ejecutado')
finally:
    print('Proceso terminado')
# Out:
# Archivo no encontrado
# Proceso terminado

# %%
#Debugging de archivos Python. Generar una celda con una operación matemática simple (p.ej. La suma de 4 números y esta suma dividida para cero),
# y mostrar los diferentes pasos que se siguieron haciendo su debugging
b = int(input('Ingresa un divisor'))
try:
    a = (1 + 2 + 3 + 4) / b
    print('Resultado: ', a)
except ZeroDivisionError:
    print("Divisor debe ser entero positivo. Ingresa un nuevo divisor")
else:
    print('El resultado es: {}'.format(a))
# Out:
# Resultado:  1.1111111111111112
# El resultado es: 1.1111111111111112
